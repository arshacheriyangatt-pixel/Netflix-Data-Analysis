# %% [markdown]
# # ****NETFLIX ANALYSIS****

# %% [markdown]
# ### ***PROBLEM STATEMENT***

# %% [markdown]
#        With the rapid expansion of digital streaming platforms,Netflix has developed a vast library of movies and Tv shows across different countries,types and durations.However,understanding the patterns within this large dataset is essential to identify trends in content production,audience targeting and platform growth.
#
#       This project aims to analayse the Netflix dataset to explore the distribution and characteristics of content available on the platform.The study focuses on identifying patterns in content type(Movies v/s Tv show),release trends over the years,country wise contributions,rating classification and duration.

# %% [markdown]
# ### ***ABOUT THE DATASET***

# %% [markdown]
#        - The dataset used in this project is the Netflix Dataset. It contains information about movies and TV shows on Netflix.There are about 8,807 records in the dataset.
#      - It includes details like title, type, director, cast, country, release year, rating, duration, and genre.Some data was missing, so it was cleaned.
#       - The duration column was also corrected. Movies are measured in minutes, and TV shows are measured in seasons.
#      - This dataset helps us understand Netflix content, such as popular genres, release trends, and   audience types. It is useful for learning data analysis.

# %% [markdown]
# ### ***AIM OF THE PROJECT***

# %% [markdown]
#       The aim of this project is to understand Netflix content. It helps to analyze movies and TV shows, find popular genres, study release year trends, and understand audience ratings. It is mainly used to learn data analysis and visualization.

# %% [markdown]
# -----

# %% [markdown]
# DAY 1

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd  #data handling
import matplotlib.pyplot as plt #visualization
import seaborn as sns #visualization

# %% [markdown]
# -------

# %% [markdown]
# DAY 2

# %% [markdown]
# ### **Loading Dataset**

# %%
df=pd.read_csv("netflix.csv")
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# -------

# %% [markdown]
# ### **Inspect Data**

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...

# %%
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                             country          date_added  \
# 8797  United States, France, South Korea, Indonesia  September 13, 2018
# 8798                                          India   December 31, 2019
# 8799                                          India   February 15, 2018
# 8800                                       Pakistan   December 15, 2016
# 8801                   United Arab Emirates, Jordan       March 9, 2016
# 8802                                  United States   November 20, 2019
# 8803                                            NaN        July 1, 2019
# 8804                                  United States    November 1, 2019
# 8805                                  United States    January 11, 2020
# 8806                                          India       March 2, 2019
#
#       release_year rating   duration  \
# 8797          2016  TV-Y7  3 Seasons
# 8798          2014  TV-MA    131 min
# 8799          2009  TV-14    120 min
# 8800          2012  TV-PG   1 Season
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8803          2018  TV-Y7  2 Seasons
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                               listed_in  \
# 8797                                           Kids' TV
# 8798             Comedies, Dramas, International Movies
# 8799                       Dramas, International Movies
# 8800  International TV Shows, Romantic TV Shows, TV ...
# 8801            Dramas, International Movies, Thrillers
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 8797  Teen surfer Zak Storm is mysteriously transpor...
# 8798  A philandering small-town mechanic's political...
# 8799  A change in the leadership of a political part...
# 8800  Strong-willed, middle-class Kashaf and carefre...
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.sample(10)
# Out:
#      show_id     type                            title  \
# 3366   s3367    Movie                 Little Miss Sumo
# 8624   s8625    Movie     Tremors 4: The Legend Begins
# 7863   s7864    Movie     Revenge of the Green Dragons
# 7864   s7865  TV Show                 Revolting Rhymes
# 801     s802    Movie  Never Back Down 2: The Beatdown
# 3791   s3792    Movie                          Pegasus
# 6404   s6405  TV Show                  Calico Critters
# 7548   s7549    Movie                   My True Friend
# 21       s22  TV Show           Resurrection: Ertugrul
# 822     s823    Movie                         The Wind
#
#                               director  \
# 3366                          Matt Kay
# 8624                       S.S. Wilson
# 7863  Andrew Lau Wai-Keung, Andrew Loo
# 7864        Jani Lachauer, Jakob Schuh
# 801                  Michael Jai White
# 3791                           Han Han
# 6404                               NaN
# 7548                Atsajun Sattakovit
# 21                                 NaN
# 822                         Emma Tammi
#
#                                                    cast  \
# 3366                                         Hiyori Kon
# 8624  Michael Gross, Sara Botsford, Billy Drago, Bre...
# 7863  Ray Liotta, Justin Chon, Kevin Wu, Harry Shum ...
# 7864  Rob Brydon, Bertie Carvel, Gemma Chan, Dominic...
# 801   Michael Jai White, Dean Geyer, Alex Meraz, Tod...
# 3791  Shen Teng, Yin Zheng, Johnny Huang, Zhang Beny...
# 6404  Georgie Fuller, Jessica Hinds-Mingo, Mayumi Ka...
# 7548  Mario Maurer, Natcha Juntapan, Monchanok Saeng...
# 21    Engin Altan Düzyatan, Serdar Gökhan, Hülya Dar...
# 822   Caitlin Gerard, Julia Goldani Telles, Ashley Z...
#
#                        country          date_added  release_year rating  \
# 3366            United Kingdom    October 28, 2019          2018   TV-G
# 8624             United States     January 1, 2020          2004  PG-13
# 7863  Hong Kong, United States       July 21, 2018          2014      R
# 7864            United Kingdom    February 1, 2018          2017  TV-PG
# 801              United States        June 2, 2021          2011      R
# 3791                     China        May 31, 2019          2019  TV-MA
# 6404                       NaN    November 1, 2018          2018   TV-Y
# 7548                  Thailand       July 25, 2018          2012  TV-MA
# 21                      Turkey  September 22, 2021          2018  TV-14
# 822              United States        June 2, 2021          2019      R
#
#        duration                                          listed_in  \
# 3366     20 min  Documentaries, International Movies, Sports Mo...
# 8624    101 min          Comedies, Horror Movies, Sci-Fi & Fantasy
# 7863     95 min     Action & Adventure, Dramas, Independent Movies
# 7864   1 Season                         British TV Shows, Kids' TV
# 801     104 min          Action & Adventure, Dramas, Sports Movies
# 3791     98 min             Comedies, Dramas, International Movies
# 6404   1 Season                                           Kids' TV
# 7548    108 min   Action & Adventure, Dramas, International Movies
# 21    5 Seasons  International TV Shows, TV Action & Adventure,...
# 822      88 min                                      Horror Movies
#
#                                             description
# 3366  In an ancient sport traditionally reserved for...
# 8624  Residents of a abandoned mining town attempt t...
# 7863  In gritty 1980s New York, two Chinese immigran...
# 7864  Popular fairy tales take on a darkly comic edg...
# 801   A group of mixed martial arts fighters stars i...
# 3791  After a five-year suspension, a once-legendary...
# 6404  The adorable residents of Sylvanian Village al...
# 7548  A bullied student forms a bond with the leader...
# 21    When a good deed unwittingly endangers his cla...
# 822   Isolated on a wind-ravaged 19th-century homest...

# %% [markdown]
# -------

# %% [markdown]
# ### **Check Column Data Types**

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ----

# %% [markdown]
# ### **Display Column Names**

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# -----

# %% [markdown]
# ### **Display no.of Columns and Rows**

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# -----

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# - Total 12 columns
# - Total entries 8807
# - Memory usage : 825.8+ KB
# - Missing values(director):2634
# - Missing values(cast):825
# - Missing values(country):831
# - Missing values(data_added):10
# - Missing values(rating):4
# - Data type mistake(duration):duration is not in object it is int64

# %% [markdown]
# ----

# %% [markdown]
# ### **Selecting Columns**

# %%
df["type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
df["title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df["cast"]
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %%
df["country"]
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %% [markdown]
# ### **Selecting Multiple Columns**

# %%
df[["type","title"]]
# Out:
#          type                  title
# 0       Movie   Dick Johnson Is Dead
# 1     TV Show          Blood & Water
# 2     TV Show              Ganglands
# 3     TV Show  Jailbirds New Orleans
# 4     TV Show           Kota Factory
# ...       ...                    ...
# 8802    Movie                 Zodiac
# 8803  TV Show            Zombie Dumb
# 8804    Movie             Zombieland
# 8805    Movie                   Zoom
# 8806    Movie                 Zubaan
#
# [8807 rows x 2 columns]

# %%
new = df[["title","director"]]

# %%
new
# Out:
#                       title         director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water              NaN
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              NaN
# 4              Kota Factory              NaN
# ...                     ...              ...
# 8802                 Zodiac    David Fincher
# 8803            Zombie Dumb              NaN
# 8804             Zombieland  Ruben Fleischer
# 8805                   Zoom     Peter Hewitt
# 8806                 Zubaan      Mozez Singh
#
# [8807 rows x 2 columns]

# %% [markdown]
# -----

# %% [markdown]
# ### **Filter the Data**

# %%
df[df["release_year"]<1945]
# Out:
#      show_id     type                                             title  \
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                    Prelude to War
# 8205   s8206    Movie                              The Battle of Midway
# 8419   s8420    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 8436   s8437    Movie                                 The Negro Soldier
# 8640   s8641    Movie                                  Tunisian Victory
# 8660   s8661    Movie     Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie                Why We Fight: The Battle of Russia
# 8763   s8764    Movie                   WWII: Report from the Aleutians
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# 8205                                          John Ford
# 8419                                      William Wyler
# 8436                                     Stuart Heisler
# 8640  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
# 8660                                          John Ford
# 8739                        Frank Capra, Anatole Litvak
# 8763                                        John Huston
#
#                            cast                        country  \
# 4250                        NaN                            NaN
# 7790                        NaN                  United States
# 8205  Henry Fonda, Jane Darwell                  United States
# 8419                        NaN                  United States
# 8436                        NaN                  United States
# 8640           Burgess Meredith  United States, United Kingdom
# 8660                        NaN                  United States
# 8739                        NaN                  United States
# 8763                        NaN                  United States
#
#              date_added  release_year rating  duration  \
# 4250  December 30, 2018          1925  TV-14  1 Season
# 7790     March 31, 2017          1942  TV-14    52 min
# 8205     March 31, 2017          1942  TV-14    18 min
# 8419     March 31, 2017          1944  TV-PG    40 min
# 8436     March 31, 2017          1944  TV-14    40 min
# 8640     March 31, 2017          1944  TV-14    76 min
# 8660     March 31, 2017          1943  TV-PG    61 min
# 8739     March 31, 2017          1943  TV-PG    82 min
# 8763     March 31, 2017          1943  TV-PG    45 min
#
#                           listed_in  \
# 4250                       TV Shows
# 7790  Classic Movies, Documentaries
# 8205  Classic Movies, Documentaries
# 8419  Classic Movies, Documentaries
# 8436  Classic Movies, Documentaries
# 8640  Classic Movies, Documentaries
# 8660  Classic Movies, Documentaries
# 8739                  Documentaries
# 8763                  Documentaries
#
#                                             description
# 4250  This collection restores films from women who ...
# 7790  Frank Capra's documentary chronicles the rise ...
# 8205  Director John Ford captures combat footage of ...
# 8419  This documentary centers on the crew of the B-...
# 8436  This documentary urged African Americans to en...
# 8640  British and American troops join forces to lib...
# 8660  This World War II-era training film dramatizes...
# 8739  This installment of Frank Capra's acclaimed do...
# 8763  Filmmaker John Huston narrates this Oscar-nomi...

# %%
df[df["type"]=="Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 6                                                   NaN  September 24, 2021
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                         United States  September 24, 2021
# 12                              Germany, Czech Republic  September 23, 2021
# ...                                                 ...                 ...
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8802                                      United States   November 20, 2019
# 8804                                      United States    November 1, 2019
# 8805                                      United States    January 11, 2020
# 8806                                              India       March 2, 2019
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8801          2015  TV-MA   96 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 6     Equestria's divided. But a bright-eyed hero be...
# 7     On a photo shoot in Ghana, an American model s...
# 9     A woman adjusting to life after a loss contend...
# 12    After most of her family is murdered in a terr...
# ...                                                 ...
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [6131 rows x 12 columns]

# %%
df[df["country"]=="India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 50    Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India
# 66                                                  NaN   India
# ...                                                 ...     ...
# 8773  Ankush Choudhary, Smita Shewale, Mohan Joshi, ...   India
# 8775  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...   India
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...   India
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...   India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#               date_added  release_year rating   duration  \
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# 24    September 21, 2021          1998  TV-14    166 min
# 39    September 16, 2021          2021  TV-Y7  3 Seasons
# 50    September 15, 2021          2014  TV-PG   1 Season
# 66    September 15, 2021          2014   TV-G   1 Season
# ...                  ...           ...    ...        ...
# 8773     January 1, 2018          2006  TV-PG    151 min
# 8775     August 31, 2018          2018  TV-PG   1 Season
# 8798   December 31, 2019          2014  TV-MA    131 min
# 8799   February 15, 2018          2009  TV-14    120 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 4     International TV Shows, Romantic TV Shows, TV ...
# 24      Comedies, International Movies, Romantic Movies
# 39                                             Kids' TV
# 50    International TV Shows, TV Dramas, TV Sci-Fi &...
# 66                   Docuseries, International TV Shows
# ...                                                 ...
# 8773             Comedies, Dramas, International Movies
# 8775                International TV Shows, TV Comedies
# 8798             Comedies, Dramas, International Movies
# 8799                       Dramas, International Movies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 4     In a city of coaching centers known to train I...
# 24    When the father of the man she loves insists t...
# 39    A brave, energetic little boy with superhuman ...
# 50    After the ancient Great War, the god Chitragup...
# 66    Explore the history and flavors of regional In...
# ...                                                 ...
# 8773  Thanks to an arranged marriage that was design...
# 8775  In the summer of 1998, middle child Harshu bal...
# 8798  A philandering small-town mechanic's political...
# 8799  A change in the leadership of a political part...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [972 rows x 12 columns]

# %%
df[df["listed_in"]=="Dramas"]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142   Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162   Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
# 329   Leonardo DiCaprio, Tom Hanks, Christopher Walk...
# ...                                                 ...
# 8674  Hugh Bonneville, Gillian Anderson, Manish Daya...
# 8675  Patrick Davis, Lisa Vidal, Josh Pence, José Zú...
# 8685  Connor Swindells, Fola Evans-Akingbola, Nichol...
# 8691  Bryan Cranston, Jennifer Garner, Jason O'Mara,...
# 8696  Emily Watson, David Thewlis, Peter Mullan, Nie...
#
#                               country         date_added  release_year rating  \
# 112                               NaN  September 3, 2021          2021  PG-13
# 129            Germany, United States  September 1, 2021          2005  PG-13
# 142            Germany, United States  September 1, 2021          2007  PG-13
# 162   United States, China, Hong Kong  September 1, 2021          2017  PG-13
# 329             United States, Canada     August 1, 2021          2002  PG-13
# ...                               ...                ...           ...    ...
# 8674    United Kingdom, India, Sweden  December 12, 2017          2017     NR
# 8675                    United States      July 24, 2017          2015  PG-13
# 8685                   United Kingdom      June 19, 2019          2018  TV-MA
# 8691                    United States      March 2, 2019          2016      R
# 8696             United States, India        May 6, 2019          2011  PG-13
#
#      duration listed_in                                        description
# 112   119 min    Dramas  In the wake of the Sept. 11 attacks, a lawyer ...
# 129   108 min    Dramas  A grieving widow and her daughter move in with...
# 142   124 min    Dramas  While her at-risk students are reading classic...
# 162   118 min    Dramas  This biopic of Thurgood Marshall, the first Bl...
# 329   142 min    Dramas  An FBI agent makes it his mission to put cunni...
# ...       ...       ...                                                ...
# 8674  106 min    Dramas  As viceroy Lord Mountbatten arrives in Delhi t...
# 8675  110 min    Dramas  In 1962 Brooklyn, a Puerto Rican teen who join...
# 8685   99 min    Dramas  A young man in foster care finds his voice in ...
# 8691  109 min    Dramas  An unhappy father and lawyer quits his suburba...
# 8696  147 min    Dramas  During World War I, the bond between a young E...
#
# [138 rows x 12 columns]

# %%
df[df["show_id"]=="s330"]
# Out:
#     show_id   type                title          director  \
# 329    s330  Movie  Catch Me If You Can  Steven Spielberg
#
#                                                   cast                country  \
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...  United States, Canada
#
#          date_added  release_year rating duration listed_in  \
# 329  August 1, 2021          2002  PG-13  142 min    Dramas
#
#                                            description
# 329  An FBI agent makes it his mission to put cunni...

# %%
df[df["director"]=="Steven Spielberg"]
# Out:
#      show_id   type                                              title  \
# 41       s42  Movie                                               Jaws
# 329     s330  Movie                                Catch Me If You Can
# 1203   s1204  Movie                                            The BFG
# 7070   s7071  Movie  Indiana Jones and the Kingdom of the Crystal S...
# 7071   s7072  Movie                 Indiana Jones and the Last Crusade
# 7072   s7073  Movie      Indiana Jones and the Raiders of the Lost Ark
# 7073   s7074  Movie               Indiana Jones and the Temple of Doom
# 7308   s7309  Movie                                            Lincoln
# 7957   s7958  Movie                                   Schindler's List
# 8184   s8185  Movie                           The Adventures of Tintin
# 8696   s8697  Movie                                          War Horse
#
#               director                                               cast  \
# 41    Steven Spielberg  Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# 329   Steven Spielberg  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
# 1203  Steven Spielberg  Mark Rylance, Ruby Barnhill, Penelope Wilton, ...
# 7070  Steven Spielberg  Harrison Ford, Cate Blanchett, Karen Allen, Ra...
# 7071  Steven Spielberg  Harrison Ford, Sean Connery, Denholm Elliott, ...
# 7072  Steven Spielberg  Harrison Ford, Karen Allen, Paul Freeman, Rona...
# 7073  Steven Spielberg  Harrison Ford, Kate Capshaw, Amrish Puri, Rosh...
# 7308  Steven Spielberg  Daniel Day-Lewis, Sally Field, David Strathair...
# 7957  Steven Spielberg  Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...
# 8184  Steven Spielberg  Jamie Bell, Andy Serkis, Daniel Craig, Nick Fr...
# 8696  Steven Spielberg  Emily Watson, David Thewlis, Peter Mullan, Nie...
#
#                                          country          date_added  \
# 41                                 United States  September 16, 2021
# 329                        United States, Canada      August 1, 2021
# 1203        United States, India, United Kingdom      March 15, 2021
# 7070                               United States     January 1, 2019
# 7071                               United States     January 1, 2019
# 7072                               United States     January 1, 2019
# 7073                               United States     January 1, 2019
# 7308                        United States, India   February 21, 2018
# 7957                               United States       April 1, 2018
# 8184  United States, New Zealand, United Kingdom   November 20, 2019
# 8696                        United States, India         May 6, 2019
#
#       release_year rating duration  \
# 41            1975     PG  124 min
# 329           2002  PG-13  142 min
# 1203          2016     PG  118 min
# 7070          2008  PG-13  123 min
# 7071          1989  PG-13  127 min
# 7072          1981     PG  116 min
# 7073          1984     PG  119 min
# 7308          2012  PG-13  150 min
# 7957          1993      R  195 min
# 8184          2011     PG  107 min
# 8696          2011  PG-13  147 min
#
#                                               listed_in  \
# 41           Action & Adventure, Classic Movies, Dramas
# 329                                              Dramas
# 1203                   Children & Family Movies, Dramas
# 7070  Action & Adventure, Children & Family Movies, ...
# 7071  Action & Adventure, Children & Family Movies, ...
# 7072  Action & Adventure, Children & Family Movies, ...
# 7073  Action & Adventure, Children & Family Movies, ...
# 7308                                             Dramas
# 7957                             Classic Movies, Dramas
# 8184                           Children & Family Movies
# 8696                                             Dramas
#
#                                             description
# 41    When an insatiable great white shark terrorize...
# 329   An FBI agent makes it his mission to put cunni...
# 1203  A little orphan meets up with a kind giant who...
# 7070  Indiana Jones is drawn into a Russian plot to ...
# 7071  Accompanied by his father, Indiana Jones sets ...
# 7072  When Indiana Jones is hired by the government ...
# 7073  Indiana Jones, his young sidekick and a spoile...
# 7308  Director Steven Spielberg takes on the towerin...
# 7957  Oskar Schindler becomes an unlikely humanitari...
# 8184  This 3-D motion capture adapts Georges Remi's ...
# 8696  During World War I, the bond between a young E...

# %% [markdown]
# ### **Filtering With Multiple Condition**

# %%
df[(df["country"]=="India")&(df["release_year"]<2026)]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 50    Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India
# 66                                                  NaN   India
# ...                                                 ...     ...
# 8773  Ankush Choudhary, Smita Shewale, Mohan Joshi, ...   India
# 8775  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...   India
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...   India
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...   India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#               date_added  release_year rating   duration  \
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# 24    September 21, 2021          1998  TV-14    166 min
# 39    September 16, 2021          2021  TV-Y7  3 Seasons
# 50    September 15, 2021          2014  TV-PG   1 Season
# 66    September 15, 2021          2014   TV-G   1 Season
# ...                  ...           ...    ...        ...
# 8773     January 1, 2018          2006  TV-PG    151 min
# 8775     August 31, 2018          2018  TV-PG   1 Season
# 8798   December 31, 2019          2014  TV-MA    131 min
# 8799   February 15, 2018          2009  TV-14    120 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 4     International TV Shows, Romantic TV Shows, TV ...
# 24      Comedies, International Movies, Romantic Movies
# 39                                             Kids' TV
# 50    International TV Shows, TV Dramas, TV Sci-Fi &...
# 66                   Docuseries, International TV Shows
# ...                                                 ...
# 8773             Comedies, Dramas, International Movies
# 8775                International TV Shows, TV Comedies
# 8798             Comedies, Dramas, International Movies
# 8799                       Dramas, International Movies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 4     In a city of coaching centers known to train I...
# 24    When the father of the man she loves insists t...
# 39    A brave, energetic little boy with superhuman ...
# 50    After the ancient Great War, the god Chitragup...
# 66    Explore the history and flavors of regional In...
# ...                                                 ...
# 8773  Thanks to an arranged marriage that was design...
# 8775  In the summer of 1998, middle child Harshu bal...
# 8798  A philandering small-town mechanic's political...
# 8799  A change in the leadership of a political part...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [972 rows x 12 columns]

# %%
df[(df["type"]=="Movie")&(df["country"]=="India")]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 105   Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India
# 114   Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Jo...   India
# 116   Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India
# 118   Akshay Oberoi, Pankaj Tripathi, Ragini Khanna,...   India
# ...                                                 ...     ...
# 8772  Dharmendra, Sunny Deol, Bobby Deol, Neha Sharm...   India
# 8773  Ankush Choudhary, Smita Shewale, Mohan Joshi, ...   India
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...   India
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...   India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#               date_added  release_year rating duration  \
# 24    September 21, 2021          1998  TV-14  166 min
# 105    September 5, 2021          2017  TV-14  128 min
# 114    September 2, 2021          1994  TV-14  143 min
# 116    September 2, 2021          2015  TV-PG  114 min
# 118    September 2, 2021          2017  TV-14  106 min
# ...                  ...           ...    ...      ...
# 8772         May 1, 2017          2013  TV-14  147 min
# 8773     January 1, 2018          2006  TV-PG  151 min
# 8798   December 31, 2019          2014  TV-MA  131 min
# 8799   February 15, 2018          2009  TV-14  120 min
# 8806       March 2, 2019          2015  TV-14  111 min
#
#                                               listed_in  \
# 24      Comedies, International Movies, Romantic Movies
# 105                Action & Adventure, Comedies, Dramas
# 114             Dramas, International Movies, Thrillers
# 116                Comedies, Dramas, Independent Movies
# 118             Dramas, International Movies, Thrillers
# ...                                                 ...
# 8772  Action & Adventure, Comedies, International Mo...
# 8773             Comedies, Dramas, International Movies
# 8798             Comedies, Dramas, International Movies
# 8799                       Dramas, International Movies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 24    When the father of the man she loves insists t...
# 105   After growing up amidst the gang wars of his h...
# 114   A wealthy industrialist’s dangerous obsession ...
# 116   A movie-loving 10-year-old and her blind littl...
# 118   When the daughter of a wealthy family returns ...
# ...                                                 ...
# 8772  Up to his old tricks, con man Dharam poses as ...
# 8773  Thanks to an arranged marriage that was design...
# 8798  A philandering small-town mechanic's political...
# 8799  A change in the leadership of a political part...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [893 rows x 12 columns]

# %% [markdown]
# -----

# %% [markdown]
# ### **Selecting Rows - iloc Method**

# %%
df.iloc[1130]  # single row
# Out:
# show_id                                                     s1131
# type                                                        Movie
# title                Seven Souls in the Skull Castle: Season Bird
# director                                           Hidenori Inoue
# cast            Sadao Abe, Mirai Moriyama, Taichi Saotome, Yas...
# country                                                       NaN
# date_added                                          April 1, 2021
# release_year                                                 2017
# rating                                                      TV-14
# duration                                                  182 min
# listed_in        Action & Adventure, Dramas, International Movies
# description     Japan, 1590. Wandering samurai band together t...
# Name: 1130, dtype: object

# %%
df.iloc[199:222]   #portion
# Out:
#     show_id     type                                        title  \
# 199    s200    Movie                                   Koi Aap Sa
# 200    s201    Movie                              Krishna Cottage
# 201    s202    Movie                                 Kucch To Hai
# 202    s203    Movie                            Kyaa Kool Hai Hum
# 203    s204    Movie                         Kyaa Kool Hain Hum 3
# 204    s205    Movie                     Kyaa Super Kool Hain Hum
# 205    s206    Movie            Kyo Kii... Main Jhuth Nahin Bolta
# 206    s207    Movie                    LSD: Love, Sex Aur Dhokha
# 207    s208    Movie    Mission Istaanbul: Darr Ke Aagey Jeet Hai
# 208    s209    Movie                  Once Upon a Time in Mumbaai
# 209    s210    Movie          Once Upon a Time in Mumbai Dobaara!
# 210    s211    Movie                                   Ragini MMS
# 211    s212    Movie                                 Ragini MMS 2
# 212    s213  TV Show                                    Rebellion
# 213    s214  TV Show                                 RIDE ON TIME
# 214    s215    Movie                  SAS: Rise of the Black Swan
# 215    s216    Movie                      Shootout at Lokhandwala
# 216    s217    Movie                             Shor In the City
# 217    s218    Movie                            The Dirty Picture
# 218    s219  TV Show                               Titletown High
# 219    s220  TV Show                                   EDENS ZERO
# 220    s221  TV Show                               Family Reunion
# 221    s222    Movie  Bob Ross: Happy Accidents, Betrayal & Greed
#
#                        director  \
# 199                Partho Mitra
# 200               Santram Varma
# 201  Anil V. Kumar, Anurag Basu
# 202              Sangeeth Sivan
# 203                Umesh Ghadge
# 204                Sachin Yardi
# 205                David Dhawan
# 206            Dibakar Banerjee
# 207              Apoorva Lakhia
# 208               Milan Luthria
# 209               Milan Luthria
# 210             Pawan Kripalani
# 211               Bhushan Patel
# 212                         NaN
# 213                         NaN
# 214              Magnus Martens
# 215              Apoorva Lakhia
# 216  Raj Nidimoru, Krishna D.K.
# 217               Milan Luthria
# 218                         NaN
# 219                         NaN
# 220                         NaN
# 221                 Joshua Rofé
#
#                                                   cast        country  \
# 199  Aftab Shivdasani, Natassha, Dipannita Sharma, ...          India
# 200  Sohail Khan, Isha Koppikar, Natassha, Rati Agn...          India
# 201  Tusshar Kapoor, Esha Deol, Natassha, Vrajesh H...          India
# 202  Tusshar Kapoor, Riteish Deshmukh, Isha Koppika...          India
# 203  Tusshar Kapoor, Aftab Shivdasani, Krishna Abhi...          India
# 204  Tusshar Kapoor, Riteish Deshmukh, Anupam Kher,...          India
# 205  Govinda, Sushmita Sen, Rambha, Anupam Kher, Sa...          India
# 206  Nushrat Bharucha, Anshuman Jha, Neha Chauhan, ...          India
# 207  Vivek Oberoi, Zayed Khan, Shriya Saran, Nikiti...          India
# 208  Ajay Devgn, Emraan Hashmi, Kangana Ranaut, Pra...          India
# 209  Akshay Kumar, Imran Khan, Sonakshi Sinha, Sona...          India
# 210  Kainaz Motivala, Rajkummar Rao, Rajat Kaul, Ja...          India
# 211  Sunny Leone, Saahil Prem, Parvin Dabas, Sandhy...          India
# 212  Charlie Murphy, Ruth Bradley, Sarah Greene, Br...        Ireland
# 213  King & Prince, Hey! Say! JUMP, KAT-TUN, NEWS, ...            NaN
# 214  Sam Heughan, Ruby Rose, Andy Serkis, Hannah Jo...            NaN
# 215  Amitabh Bachchan, Sanjay Dutt, Sunil Shetty, A...          India
# 216  Sendhil Ramamurthy, Tusshar Kapoor, Nikhil Dwi...          India
# 217  Vidya Balan, Emraan Hashmi, Tusshar Kapoor, Na...          India
# 218                                                NaN            NaN
# 219  Takuma Terashima, Mikako Komatsu, Rie Kugimiya...          Japan
# 220  Loretta Devine, Tia Mowry-Hardrict, Anthony Al...  United States
# 221                                           Bob Ross            NaN
#
#           date_added  release_year rating   duration  \
# 199  August 27, 2021          2006  TV-14    135 min
# 200  August 27, 2021          2004  TV-14    124 min
# 201  August 27, 2021          2003  TV-14    136 min
# 202  August 27, 2021          2005  TV-MA    165 min
# 203  August 27, 2021          2016  TV-MA    124 min
# 204  August 27, 2021          2012  TV-MA    136 min
# 205  August 27, 2021          2001  TV-14    150 min
# 206  August 27, 2021          2010  TV-MA    112 min
# 207  August 27, 2021          2008  TV-14    119 min
# 208  August 27, 2021          2010  TV-14    133 min
# 209  August 27, 2021          2013  TV-14    142 min
# 210  August 27, 2021          2011  TV-MA     93 min
# 211  August 27, 2021          2014  TV-MA    113 min
# 212  August 27, 2021          2016  TV-MA  2 Seasons
# 213  August 27, 2021          2021  TV-PG  3 Seasons
# 214  August 27, 2021          2021      R    124 min
# 215  August 27, 2021          2007  TV-MA    116 min
# 216  August 27, 2021          2011  TV-14    106 min
# 217  August 27, 2021          2011  TV-14    145 min
# 218  August 27, 2021          2021  TV-14   1 Season
# 219  August 26, 2021          2021  TV-14   1 Season
# 220  August 26, 2021          2021  TV-PG  4 Seasons
# 221  August 25, 2021          2021  TV-14     93 min
#
#                                              listed_in  \
# 199             Comedies, Dramas, International Movies
# 200  Action & Adventure, Horror Movies, Internation...
# 201            Dramas, International Movies, Thrillers
# 202   Comedies, International Movies, Music & Musicals
# 203                     Comedies, International Movies
# 204                     Comedies, International Movies
# 205   Comedies, International Movies, Sci-Fi & Fantasy
# 206   Dramas, Independent Movies, International Movies
# 207  Action & Adventure, International Movies, Musi...
# 208     Dramas, International Movies, Music & Musicals
# 209     Dramas, International Movies, Music & Musicals
# 210                Horror Movies, International Movies
# 211                Horror Movies, International Movies
# 212                  International TV Shows, TV Dramas
# 213                 Docuseries, International TV Shows
# 214           Action & Adventure, International Movies
# 215   Action & Adventure, Dramas, International Movies
# 216               Comedies, Dramas, Independent Movies
# 217             Comedies, Dramas, International Movies
# 218                          Reality TV, Teen TV Shows
# 219               Anime Series, International TV Shows
# 220                              Kids' TV, TV Comedies
# 221                                      Documentaries
#
#                                            description
# 199  Star athlete Rohan has his eye on a beautiful ...
# 200  True love is put to the test when another woma...
# 201  A student tries to steal a test from a teacher...
# 202  Longtime friends Rahul and Karan head to Mumba...
# 203  When an unlikely porn actor falls for a woman ...
# 204  An aspiring actor and a struggling DJ team up ...
# 205  The life and career of a lawyer are thrown int...
# 206  This provocative drama examines how the voyeur...
# 207  A television journalist makes a risky career m...
# 208  Mumbai's top mob boss rules the underworld wit...
# 209  This turbulent sequel to Once Upon a Time in M...
# 210  A couple out to have a sensuous weekend at a h...
# 211  The horror continues when Ragini's video goes ...
# 212  As World War I rages, three women and their fa...
# 213  Take a deep dive into the beautiful world of J...
# 214  A special forces operative traveling from Lond...
# 215  Based on a true story, this action film follow...
# 216  When three small-time Mumbai crooks steal a ba...
# 217  After running away from home in search of movi...
# 218  In a Georgia town where football rules and win...
# 219  Aboard the Edens Zero, a lonely boy with the a...
# 220  When the McKellan family moves from Seattle to...
# 221  Bob Ross brought joy to millions as the world’...

# %% [markdown]
# ### **Loc method**

# %%
df.loc[500,"type"]
# Out:
# 'Movie'

# %%
df.loc[500,"release_year"]
# Out:
# np.int64(2021)

# %% [markdown]
# ----

# %% [markdown]
# ### **Rename Column**

# %%
df.rename(columns={"listed_in":"genres"},inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                                  genres  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# -----

# %% [markdown]
# ###  **Value Count**

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
df["description"].value_counts()
# Out:
# description
# Paranormal activity at a lush, abandoned property alarms a group eager to redevelop the site, but the eerie events may not be as unearthly as they think.    4
# Challenged to compose 100 songs before he can marry the girl he loves, a tortured but passionate singer-songwriter embarks on a poignant musical journey.    3
# A surly septuagenarian gets another chance at her 20s after having her photo snapped at a studio that magically takes 50 years off her life.                 3
# Multiple women report their husbands as missing but when it appears they are looking for the same man, a police officer traces their cryptic connection.     3
# Secrets bubble to the surface after a sensual encounter and an unforeseen crime entangle two friends and a woman caught between them.                        2
#                                                                                                                                                             ..
# Sent away to evade an arranged marriage, a 14-year-old begins a harrowing journey of sex work and poverty in the slums of Accra.                             1
# When his partner in crime goes missing, a small-time crook’s life is transformed as he dedicates himself to raising the daughter his friend left behind.     1
# During 1962’s Cuban missile crisis, a troubled math genius finds himself drafted to play in a U.S.-Soviet chess match – and a deadly game of espionage.      1
# A teen's discovery of a vintage Polaroid camera develops into a darker tale when she finds that whoever takes their photo with it dies soon afterward.       1
# A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.                      1
# Name: count, Length: 8775, dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# DAY 3

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# #### Clean Numerical columns with characters

# %%
#df["engine"]=pd.to_numeric(
#  df["engine"]
#   .astype(str)
#   .str.replace(r'[^0-9.-]','',regex=True)
#   .replace('',None),
#   errors='coerce'
#)

# %% [markdown]
# #####     parse date_added as datetime

# %%
df["date_added"]=pd.to_datetime(df["date_added"],
                                errors="coerce")

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# genres                  object
# description             object
# dtype: object

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
import pandas as pd

def categorize_rating(rating):
    if pd.isna(rating):
        return "Unknown"
    
    rating = str(rating).strip()

    # Handle wrong entries like durations
    if "min" in rating:
        return "Unknown"
    
    # Kids content
    if rating in ["TV-Y", "TV-Y7", "TV-Y7-FV", "G"]:
        return "Kids"
    
    # Family / General
    elif rating in ["TV-G", "PG", "TV-PG"]:
        return "Family"
    
    # Teens
    elif rating in ["PG-13", "TV-14"]:
        return "Teen"
    
    # Adults
    elif rating in ["R", "TV-MA", "NC-17"]:
        return "Adult"
    
    # Not Rated / Others
    elif rating in ["NR", "UR"]:
        return "Unrated"
    
    else:
        return "Unrated"

# %%
df["rating_category"] = df["rating"].apply(categorize_rating)

# %%
print(df["rating_category"].value_counts())
# Out:
# rating_category
# Adult      4009
# Teen       2650
# Family     1370
# Kids        688
# Unrated      83
# Unknown       7
# Name: count, dtype: int64

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 0    2021-09-25          2020  PG-13     90 min
# 1    2021-09-24          2021  TV-MA  2 Seasons
# 2    2021-09-24          2021  TV-MA   1 Season
# 3    2021-09-24          2021  TV-MA   1 Season
# 4    2021-09-24          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R     88 min
# 8805 2020-01-11          2006     PG     88 min
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                                  genres  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# ...                                                 ...             ...
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8803  While living alone in a spooky town, a young g...            Kids
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [8807 rows x 13 columns]

# %% [markdown]
# -----

# %% [markdown]
# ### **Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2634
# cast                825
# country             831
# date_added           10
# release_year          0
# rating                4
# duration              3
# genres                0
# description           0
# rating_category       0
# dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# ### **How to Fill Missing Values**

# %%
df['director'].fillna("unknown",inplace= True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\4243997837.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna("unknown",inplace= True)

# %%
df['cast'].fillna("unknown",inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\2462058862.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna("unknown",inplace=True)

# %%
df['country'].fillna("unknown",inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\367023652.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna("unknown",inplace=True)

# %%
df.dropna(subset=['date_added','rating','duration'],inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                               unknown        unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            unknown        unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 0    2021-09-25          2020  PG-13     90 min
# 1    2021-09-24          2021  TV-MA  2 Seasons
# 2    2021-09-24          2021  TV-MA   1 Season
# 3    2021-09-24          2021  TV-MA   1 Season
# 4    2021-09-24          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R     88 min
# 8805 2020-01-11          2006     PG     88 min
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                                  genres  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# ...                                                 ...             ...
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8803  While living alone in a spooky town, a young g...            Kids
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [8790 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# genres             0
# description        0
# rating_category    0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 13)

# %% [markdown]
# - Data cleaned successfully

# %% [markdown]
# ------

# %% [markdown]
# ###  **Handling Duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#print("Before:",df.shape)
#df=df.drop_duplicates()
#print('After:',df.shape)

# %% [markdown]
# DAY 4

# %% [markdown]
# -----

# %% [markdown]
# ### **Ensuring Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8790 non-null   object
#  1   type             8790 non-null   object
#  2   title            8790 non-null   object
#  3   director         8790 non-null   object
#  4   cast             8790 non-null   object
#  5   country          8790 non-null   object
#  6   date_added       8790 non-null   datetime64[ns]
#  7   release_year     8790 non-null   int64
#  8   rating           8790 non-null   object
#  9   duration         8790 non-null   object
#  10  genres           8790 non-null   object
#  11  description      8790 non-null   object
#  12  rating_category  8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 961.4+ KB

# %%
df.sample(10)
# Out:
#      show_id     type                                 title        director  \
# 3967   s3968    Movie          The Legend of Cocaine Island       Theo Love
# 417     s418    Movie        Chhota Bheem in African Safari     Binayak Das
# 945     s946    Movie                      Sitting in Limbo  Stella Corradi
# 7009   s7010    Movie        House at the End of the Street   Mark Tonderai
# 2477   s2478    Movie      Living in Bondage: Breaking Free    Ramsey Nouah
# 6419   s6420    Movie                   Cardboard Gangsters   Mark O'Connor
# 8518   s8519  TV Show  The Story of God with Morgan Freeman         unknown
# 640     s641  TV Show                                 Jiva!         unknown
# 6114   s6115    Movie                     Alive and Kicking   Susan Glatzer
# 6601   s6602  TV Show         Devlok with Devdutt Pattanaik         unknown
#
#                                                    cast  \
# 3967                                            unknown
# 417   Sonal Kaushal, Rupa Bhimani, Julie Tejwani, Sa...
# 945   Patrick Robinson, Nadine Marshall, Pippa Benne...
# 7009  Gil Bellows, Max Thieriot, Jennifer Lawrence, ...
# 2477  Swanky JKA, Kenneth Okonkwo, Ramsey Nouah, Eny...
# 6419  John Connors, Fionn Walton, Kierston Wareing, ...
# 8518                                     Morgan Freeman
# 640   Noxolo Dlamini, Candice Modiselle, Sne Mbatha,...
# 6114                                            unknown
# 6601                    Rasika Dugal, Devdutt Pattanaik
#
#                     country date_added  release_year rating   duration  \
# 3967          United States 2019-03-29          2019  TV-MA     87 min
# 417                 unknown 2021-07-22          2015  TV-Y7     62 min
# 945          United Kingdom 2021-05-01          2020  TV-MA     89 min
# 7009  United States, Canada 2020-05-08          2012  PG-13    101 min
# 2477                Nigeria 2020-05-22          2019  TV-MA    149 min
# 6419                Ireland 2018-09-15          2016  TV-MA     92 min
# 8518          United States 2019-02-01          2017  TV-14  2 Seasons
# 640                 unknown 2021-06-24          2021  TV-MA   1 Season
# 6114  Sweden, United States 2017-08-10          2016  TV-14     89 min
# 6601                  India 2018-10-15          2017  TV-PG   1 Season
#
#                                               genres  \
# 3967                                   Documentaries
# 417                         Children & Family Movies
# 945                     Dramas, International Movies
# 7009                        Horror Movies, Thrillers
# 2477  Horror Movies, International Movies, Thrillers
# 6419                    Dramas, International Movies
# 8518                                      Docuseries
# 640                International TV Shows, TV Dramas
# 6114                                   Documentaries
# 6601                          International TV Shows
#
#                                             description rating_category
# 3967  An urban legend about a duffel bag of cocaine ...           Adult
# 417   Bheem’s plans for an exciting African safari a...            Kids
# 945   After living 50 years in the UK, Anthony Bryan...           Adult
# 7009  Moving to a new town proves even more stressfu...            Teen
# 2477  Mentored by an enigmatic tycoon, an ambitious ...           Adult
# 6419  A low-level drug dealer decides to move up the...           Adult
# 8518  Host Morgan Freeman explores religion's role i...            Teen
# 640   A talented street dancer from Umlazi, Durban m...           Adult
# 6114  Take an inside look at swing dancing's continu...            Teen
# 6601  Through chats with host Rasika Dugal, mytholog...          Family

# %%
df.shape
# Out:
# (8790, 13)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description',
#        'rating_category'],
#       dtype='object')

# %% [markdown]
# ----

# %% [markdown]
# ### **Filter the Data - movie and tv show**

# %%
movies = df[df['type'] == 'Movie']

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                               unknown
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 0                                         United States 2021-09-25
# 6                                               unknown 2021-09-24
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8801          2015  TV-MA   96 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                                 genres  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 6     Equestria's divided. But a bright-eyed hero be...          Family
# 7     On a photo shoot in Ghana, an American model s...           Adult
# 9     A woman adjusting to life after a loss contend...            Teen
# 12    After most of her family is murdered in a terr...           Adult
# ...                                                 ...             ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           Adult
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [6126 rows x 13 columns]

# %% [markdown]
# #### parase  movies as numerical

# %%
movies["duration"].unique
# Out:
# <bound method Series.unique of 0        90 min
# 6        91 min
# 7       125 min
# 9       104 min
# 12      127 min
#          ...
# 8801     96 min
# 8802    158 min
# 8804     88 min
# 8805     88 min
# 8806    111 min
# Name: duration, Length: 6126, dtype: object>

# %%
movies["duration"] = movies["duration"].str.replace(" min", "", regex=False)
movies["duration"]=pd.to_numeric(movies["duration"],errors="coerce")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\3675989099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["duration"] = movies["duration"].str.replace(" min", "", regex=False)
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\3675989099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["duration"]=pd.to_numeric(movies["duration"],errors="coerce")

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                               unknown
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 0                                         United States 2021-09-25
# 6                                               unknown 2021-09-24
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating  duration  \
# 0             2020  PG-13        90
# 6             2021     PG        91
# 7             1993  TV-MA       125
# 9             2021  PG-13       104
# 12            2021  TV-MA       127
# ...            ...    ...       ...
# 8801          2015  TV-MA        96
# 8802          2007      R       158
# 8804          2009      R        88
# 8805          2006     PG        88
# 8806          2015  TV-14       111
#
#                                                 genres  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 6     Equestria's divided. But a bright-eyed hero be...          Family
# 7     On a photo shoot in Ghana, an American model s...           Adult
# 9     A woman adjusting to life after a loss contend...            Teen
# 12    After most of her family is murdered in a terr...           Adult
# ...                                                 ...             ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           Adult
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [6126 rows x 13 columns]

# %%
movies.dtypes
# Out:
# show_id                    object
# type                       object
# title                      object
# director                   object
# cast                       object
# country                    object
# date_added         datetime64[ns]
# release_year                int64
# rating                     object
# duration                    int64
# genres                     object
# description                object
# rating_category            object
# dtype: object

# %%
movies.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# genres             0
# description        0
# rating_category    0
# dtype: int64

# %%
tv_shows = df[df['type'] == 'TV Show']

# %%
tv_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 8796   s8797  TV Show             Yunus Emre          unknown
# 8797   s8798  TV Show              Zak Storm          unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 8803   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8795  Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# 8796  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8803                                            unknown
#
#                                             country date_added  release_year  \
# 1                                      South Africa 2021-09-24          2021
# 2                                           unknown 2021-09-24          2021
# 3                                           unknown 2021-09-24          2021
# 4                                             India 2021-09-24          2021
# 5                                           unknown 2021-09-24          2021
# ...                                             ...        ...           ...
# 8795                                  Japan, Canada 2018-05-01          2015
# 8796                                         Turkey 2017-01-17          2016
# 8797  United States, France, South Korea, Indonesia 2018-09-13          2016
# 8800                                       Pakistan 2016-12-15          2012
# 8803                                        unknown 2019-07-01          2018
#
#      rating   duration                                             genres  \
# 1     TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA   1 Season                             Docuseries, Reality TV
# 4     TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# 5     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# ...     ...        ...                                                ...
# 8795  TV-Y7  2 Seasons                             Anime Series, Kids' TV
# 8796  TV-PG  2 Seasons                  International TV Shows, TV Dramas
# 8797  TV-Y7  3 Seasons                                           Kids' TV
# 8800  TV-PG   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 8803  TV-Y7  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description rating_category
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# 5     The arrival of a charismatic young priest brin...           Adult
# ...                                                 ...             ...
# 8795  Now that he's discovered the Pendulum Summonin...            Kids
# 8796  During the Mongol invasions, Yunus Emre leaves...          Family
# 8797  Teen surfer Zak Storm is mysteriously transpor...            Kids
# 8800  Strong-willed, middle-class Kashaf and carefre...          Family
# 8803  While living alone in a spooky town, a young g...            Kids
#
# [2664 rows x 13 columns]

# %% [markdown]
# #### Parase tv_show as numerical

# %%
tv_shows.dtypes
# Out:
# show_id                    object
# type                       object
# title                      object
# director                   object
# cast                       object
# country                    object
# date_added         datetime64[ns]
# release_year                int64
# rating                     object
# duration                   object
# genres                     object
# description                object
# rating_category            object
# dtype: object

# %%
tv_shows.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# genres             0
# description        0
# rating_category    0
# dtype: int64

# %%
tv_shows["duration"] = tv_shows["duration"].astype(str)
tv_shows["duration"] = tv_shows["duration"].str.split().str[0].astype(int)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\1184794807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows["duration"] = tv_shows["duration"].astype(str)
# C:\Users\hp\AppData\Local\Temp\ipykernel_10012\1184794807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows["duration"] = tv_shows["duration"].str.split().str[0].astype(int)

# %%
tv_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 8796   s8797  TV Show             Yunus Emre          unknown
# 8797   s8798  TV Show              Zak Storm          unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 8803   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8795  Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# 8796  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8803                                            unknown
#
#                                             country date_added  release_year  \
# 1                                      South Africa 2021-09-24          2021
# 2                                           unknown 2021-09-24          2021
# 3                                           unknown 2021-09-24          2021
# 4                                             India 2021-09-24          2021
# 5                                           unknown 2021-09-24          2021
# ...                                             ...        ...           ...
# 8795                                  Japan, Canada 2018-05-01          2015
# 8796                                         Turkey 2017-01-17          2016
# 8797  United States, France, South Korea, Indonesia 2018-09-13          2016
# 8800                                       Pakistan 2016-12-15          2012
# 8803                                        unknown 2019-07-01          2018
#
#      rating  duration                                             genres  \
# 1     TV-MA         2    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA         1  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA         1                             Docuseries, Reality TV
# 4     TV-MA         2  International TV Shows, Romantic TV Shows, TV ...
# 5     TV-MA         1                 TV Dramas, TV Horror, TV Mysteries
# ...     ...       ...                                                ...
# 8795  TV-Y7         2                             Anime Series, Kids' TV
# 8796  TV-PG         2                  International TV Shows, TV Dramas
# 8797  TV-Y7         3                                           Kids' TV
# 8800  TV-PG         1  International TV Shows, Romantic TV Shows, TV ...
# 8803  TV-Y7         2             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description rating_category
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# 5     The arrival of a charismatic young priest brin...           Adult
# ...                                                 ...             ...
# 8795  Now that he's discovered the Pendulum Summonin...            Kids
# 8796  During the Mongol invasions, Yunus Emre leaves...          Family
# 8797  Teen surfer Zak Storm is mysteriously transpor...            Kids
# 8800  Strong-willed, middle-class Kashaf and carefre...          Family
# 8803  While living alone in a spooky town, a young g...            Kids
#
# [2664 rows x 13 columns]

# %% [markdown]
# ### Save to the data file

# %%
df.to_csv('netflix_cleaned.csv',index=False)

# %%
movies.to_csv('movies.csv',index=False)

# %%
tv_shows.to_csv('tv_shows',index=False)

# %% [markdown]
# -----

# %% [markdown]
# ### **Load The New Data**

# %%
df_new=pd.read_csv('netflix_cleaned.csv')

# %%
df_new.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                            unknown        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25          2020  PG-13     90 min
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 2  2021-09-24          2021  TV-MA   1 Season
# 3  2021-09-24          2021  TV-MA   1 Season
# 4  2021-09-24          2021  TV-MA  2 Seasons
#
#                                               genres  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description rating_category
# 0  As her father nears the end of his life, filmm...            Teen
# 1  After crossing paths at a party, a Cape Town t...           Adult
# 2  To protect his family from a powerful drug lor...           Adult
# 3  Feuds, flirtations and toilet talk go down amo...           Adult
# 4  In a city of coaching centers known to train I...           Adult

# %%
df_new1=pd.read_csv('movies.csv')

# %%
df_new1.head()
# Out:
#   show_id   type                             title  \
# 0      s1  Movie              Dick Johnson Is Dead
# 1      s7  Movie  My Little Pony: A New Generation
# 2      s8  Movie                           Sankofa
# 3     s10  Movie                      The Starling
# 4     s13  Movie                      Je Suis Karl
#
#                         director  \
# 0                Kirsten Johnson
# 1  Robert Cullen, José Luis Ucha
# 2                   Haile Gerima
# 3                 Theodore Melfi
# 4            Christian Schwochow
#
#                                                 cast  \
# 0                                            unknown
# 1  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                              country  date_added  \
# 0                                      United States  2021-09-25
# 1                                            unknown  2021-09-24
# 2  United States, Ghana, Burkina Faso, United Kin...  2021-09-24
# 3                                      United States  2021-09-24
# 4                            Germany, Czech Republic  2021-09-23
#
#    release_year rating  duration  \
# 0          2020  PG-13        90
# 1          2021     PG        91
# 2          1993  TV-MA       125
# 3          2021  PG-13       104
# 4          2021  TV-MA       127
#
#                                              genres  \
# 0                                     Documentaries
# 1                          Children & Family Movies
# 2  Dramas, Independent Movies, International Movies
# 3                                  Comedies, Dramas
# 4                      Dramas, International Movies
#
#                                          description rating_category
# 0  As her father nears the end of his life, filmm...            Teen
# 1  Equestria's divided. But a bright-eyed hero be...          Family
# 2  On a photo shoot in Ghana, an American model s...           Adult
# 3  A woman adjusting to life after a loss contend...            Teen
# 4  After most of her family is murdered in a terr...           Adult

# %%
df_new2=pd.read_csv('tv_shows')

# %%
df_new2.head()
# Out:
#   show_id     type                  title         director  \
# 0      s2  TV Show          Blood & Water          unknown
# 1      s3  TV Show              Ganglands  Julien Leclercq
# 2      s4  TV Show  Jailbirds New Orleans          unknown
# 3      s5  TV Show           Kota Factory          unknown
# 4      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...       unknown
# 2                                            unknown       unknown
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...       unknown
#
#    date_added  release_year rating  duration  \
# 0  2021-09-24          2021  TV-MA         2
# 1  2021-09-24          2021  TV-MA         1
# 2  2021-09-24          2021  TV-MA         1
# 3  2021-09-24          2021  TV-MA         2
# 4  2021-09-24          2021  TV-MA         1
#
#                                               genres  \
# 0    International TV Shows, TV Dramas, TV Mysteries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                             Docuseries, Reality TV
# 3  International TV Shows, Romantic TV Shows, TV ...
# 4                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description rating_category
# 0  After crossing paths at a party, a Cape Town t...           Adult
# 1  To protect his family from a powerful drug lor...           Adult
# 2  Feuds, flirtations and toilet talk go down amo...           Adult
# 3  In a city of coaching centers known to train I...           Adult
# 4  The arrival of a charismatic young priest brin...           Adult

# %% [markdown]
# -----

# %% [markdown]
# ### **Summary Statistics**

# %% [markdown]
# ##### Mean (average)

# %%
print("release_year  - ",df_new["release_year"].mean())
# Out:
# release_year  -  2014.183162684869

# %% [markdown]
# ##### Median

# %%
print("release_year  - ",df_new["release_year"].median())
# Out:
# release_year  -  2017.0

# %% [markdown]
# ##### Mode

# %%
print("release_year  - ",df_new["release_year"].mode())
# Out:
# release_year  -  0    2018
# Name: release_year, dtype: int64

# %% [markdown]
# ##### Standard Deviation

# %%
df_new.select_dtypes(include='number').std()
# Out:
# release_year    8.825466
# dtype: float64

# %%
df_new.select_dtypes(include='number').mean()
# Out:
# release_year    2014.183163
# dtype: float64

# %%
df_new.select_dtypes(include='number').mode()
# Out:
#    release_year
# 0          2018

# %%
df_new.select_dtypes(include='object').mode()
# Out:
#      show_id   type                          title director     cast  \
# 0         s1  Movie                         #Alive  unknown  unknown
# 1        s10    NaN  #AnneFrank - Parallel Stories      NaN      NaN
# 2       s100    NaN              #FriendButMarried      NaN      NaN
# 3      s1000    NaN            #FriendButMarried 2      NaN      NaN
# 4      s1001    NaN                          #Roxy      NaN      NaN
# ...      ...    ...                            ...      ...      ...
# 8785    s995    NaN                       忍者ハットリくん      NaN      NaN
# 8786    s996    NaN                           海的儿子      NaN      NaN
# 8787    s997    NaN                           마녀사냥      NaN      NaN
# 8788    s998    NaN                        반드시 잡는다      NaN      NaN
# 8789    s999    NaN            최강전사 미니특공대 : 영웅의 탄생      NaN      NaN
#
#             country  date_added rating  duration  \
# 0     United States  2020-01-01  TV-MA  1 Season
# 1               NaN         NaN    NaN       NaN
# 2               NaN         NaN    NaN       NaN
# 3               NaN         NaN    NaN       NaN
# 4               NaN         NaN    NaN       NaN
# ...             ...         ...    ...       ...
# 8785            NaN         NaN    NaN       NaN
# 8786            NaN         NaN    NaN       NaN
# 8787            NaN         NaN    NaN       NaN
# 8788            NaN         NaN    NaN       NaN
# 8789            NaN         NaN    NaN       NaN
#
#                             genres  \
# 0     Dramas, International Movies
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 8785                           NaN
# 8786                           NaN
# 8787                           NaN
# 8788                           NaN
# 8789                           NaN
#
#                                             description rating_category
# 0     Paranormal activity at a lush, abandoned prope...           Adult
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 8785                                                NaN             NaN
# 8786                                                NaN             NaN
# 8787                                                NaN             NaN
# 8788                                                NaN             NaN
# 8789                                                NaN             NaN
#
# [8790 rows x 12 columns]

# %%
df_new.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# - The dataset contains 8790 entries.
# - The average release year is 2014, showing that most content is fairly recent.
# - The standard deviation is 8.83, which means the data is moderately spread around the mean.
# - The oldest content dates back to 1925.
# - 25% of the content was released before 2013.
# - The median release year is 2017.
# - 75% of the content was released before 2019.
# - The latest content is from 2021.

# %%
df_new.describe(include=object)
# Out:
#        show_id   type                 title director     cast        country  \
# count     8790   8790                  8790     8790     8790           8790
# unique    8790      2                  8790     4527     7679            749
# top         s1  Movie  Dick Johnson Is Dead  unknown  unknown  United States
# freq         1   6126                     1     2621      825           2809
#
#         date_added rating  duration                        genres  \
# count         8790   8790      8790                          8790
# unique        1713     14       220                           513
# top     2020-01-01  TV-MA  1 Season  Dramas, International Movies
# freq           110   3205      1791                           362
#
#                                               description rating_category
# count                                                8790            8790
# unique                                               8758               5
# top     Paranormal activity at a lush, abandoned prope...           Adult
# freq                                                    4            4007

# %% [markdown]
# - Total 8790 entries,means no missing values
# - 2 Unique values are movie and tv shows ,Dataset is heavily movie-dominated
# - Every titles are unique
# - 4527 Direcctors are unique , the most of them are unknown(2621)
# - 7679 cast are unique , most of the cast are unknown (825)
# - Most content  is dominted by the United States
# - 110 shows were released on 01/01/2020
# - Majority content is TV-MA
# - Drama & International Movies are the majority of the genre
# - Mostly target on adult audience

# %%
df_new1.describe(include=object)
# Out:
#        show_id   type                 title director     cast        country  \
# count     6126   6126                  6126     6126     6126           6126
# unique    6126      1                  6126     4353     5444            652
# top         s1  Movie  Dick Johnson Is Dead  unknown  unknown  United States
# freq         1   6126                     1      187      475           2055
#
#         date_added rating                        genres  \
# count         6126   6126                          6126
# unique        1531     14                           278
# top     2020-01-01  TV-MA  Dramas, International Movies
# freq            97   2062                           362
#
#                                               description rating_category
# count                                                6126            6126
# unique                                               6100               5
# top     Paranormal activity at a lush, abandoned prope...           Adult
# freq                                                    4            2862

# %% [markdown]
# - Total 6126 entries, means no missing
# - only movies are in the dataset
# - 4353 Directors are unique, 187 directors are unknown
# - 475 cast arev unknown
# - Most of the movies dominated by the United States
# - 97 movies were released on 01/01/2020
# - Majority content is TV-MA
# - 205 movies are unique duration,152 movies are 90 min duration
# - Drama's & International MOvies are the majority genre
# - Paranormal activity at a lush, abandoned property alarms a group eager to redevelop the site, but the eerie events may not be as unearthly as they think is the most of the movie description
# - majority movies on target on adult audience

# %%
df_new2.describe(include=object)
# Out:
#        show_id     type          title director     cast        country  \
# count     2664     2664           2664     2664     2664           2664
# unique    2664        1           2664      223     2272            197
# top         s2  TV Show  Blood & Water  unknown  unknown  United States
# freq         1     2664              1     2434      350            754
#
#         date_added rating    genres  \
# count         2664   2664      2664
# unique        1012      9       235
# top     2021-07-06  TV-MA  Kids' TV
# freq            31   1143       219
#
#                                               description rating_category
# count                                                2664            2664
# unique                                               2660               5
# top     As a psychology professor faces Alzheimer's, h...           Adult
# freq                                                    2            1145

# %% [markdown]
# - Total 2664 entries ,no missing values
# - Only tv shows are in the dataset
# - 2434 directors are unknown
# - 350 cast are unknown
# - Most of the tv shows dominated by the United States
# - 31 tv shows were released on 06/07/2021
# - majority content is TV-MA
# - 1791 tv shows are 1 season
# - kid's TV is the most genre
# - Majority tv shows target on adult audience

# %%
df_new1.describe()
# Out:
#        release_year     duration
# count   6126.000000  6126.000000
# mean    2013.120144    99.584884
# std        9.681723    28.283225
# min     1942.000000     3.000000
# 25%     2012.000000    87.000000
# 50%     2016.000000    98.000000
# 75%     2018.000000   114.000000
# max     2021.000000   312.000000

# %% [markdown]
# - The dataset contains 6126 entries.
# - The average release year is 2013, showing that most content is fairly recent.
# - The standard deviation is 9.68, which means the data is moderately spread around the mean.
# - The oldest content dates back to 1942.
# - 25% of the content was released before 2012.
# - The median release year is 2016.
# - 75% of the content was released before 2018.
# - The latest content is from 2021

# %%
df_new2.describe()
# Out:
#        release_year     duration
# count   2664.000000  2664.000000
# mean    2016.627628     1.751877
# std        5.735194     1.550622
# min     1925.000000     1.000000
# 25%     2016.000000     1.000000
# 50%     2018.000000     1.000000
# 75%     2020.000000     2.000000
# max     2021.000000    17.000000

# %% [markdown]
#  The dataset contains 2664 entries.
# - The average release year is 2016, showing that most content is fairly recent.
# - The standard deviation is 5.53, which means the data is moderately spread around the mean.
# - The oldest content dates back to 1925.
# - 25% of the content was released before 2016.
# - The median release year is 2016.
# - 75% of the content was released before 2020.
# - The latest content is from 2021

# %% [markdown]
# -----

# %% [markdown]
# DAY 5

# %% [markdown]
# ### **Data Visualization**

# %% [markdown]
# #### Univariate analysis
#      - Histogram,kde,box - numerical
#      - Count, pie - categorical
# #### Bivariate analysis
#      - Bar plot - categorical vs numerical
#      - line plot(time series) and scatter - numerical vs numerical
# #### Multivariate analysis
#      - Heatmap - correlation
#      - Pair plot - numerical

# %% [markdown]
# #### **Univariate Analysis**

# %% [markdown]
# ##### *Histogram*

# %% [markdown]
# - Distribution of continues Numerical data

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,4))
sns. histplot(data=df_new,x="release_year",bins=50)
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - A huge majority of the release happened in the last 10 - 15 years
# - There are very few releases from before the year 2000.
# - The number of releases started growing very fast after 2010.
# - 2018 and 2019 were the biggest years for releases.
# - The numbers drop suddenly after 2019.
# - Most of the data is crowded on the right side (recent years).

# %%
plt.figure(figsize=(4,4))
sns. histplot(data=df_new1,x="release_year",bins=50)
plt.title("Distribution of Release Year(Movies)")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most content is released after 2000
# - Majority of release happened in 10-15 years
# - Releases from 1940 to 1980 are very rare
# - There is a massive spike right around 2018
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020

# %%
plt.figure(figsize=(4,4))
sns. histplot(data=df_new2,x="release_year",bins=50)
plt.title("Distribution of Release Year(tv shows)")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Almost all tv shows were released after 2010
# - TV shows from 1940 to 2000 are extremely rare
# - 2019 has the most releases followed by a small drop in 2020
# - Majority of release happened in last 5-10 years

# %% [markdown]
# #### *Box Plot*

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df_new,x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - 50% of all releases happened between approximately 2013 and 2019
# - The vertical line in the box shows the middle value is around 2017
# - The long trail of circles to the left shows that releases before 2005 are rare and considered outliers

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df_new1,x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most data is concentrated in 2010–2020
# - The distribution is skewed toward recent years
# - Many older years appear as outliers
# - The median is in recent years
# - Very few entries before 2000

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df_new2,x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - The catalog is heavily weighted toward releases after 2010.
# - Adult-rated content is the largest rating group.
# - Netflix content peaks around 2018–2019 and drops after 2019.
# - TV shows are usually short-run (1–3 seasons) in this dataset.
# - Older releases (pre-2000) are rare and appear as outliers.

# %% [markdown]
# #### *Count Plot*

# %%
plt.figure(figsize=(35,4))
sns. countplot(data=df_new,x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most releaes are after 2010
# - there is only very few releases before 2000
# - Release increases quickly after 2010
# - The highest releases count are in 2018–2019
# - After 2019, counts drop a bit
# - The data is right-heavy, meaning recent years dominate

# %%
plt.figure(figsize=(35,4))
sns. countplot(data=df_new1,x="release_year")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most titles are from 2010 onward.
# - Movies far outnumber TV shows.
# - Adult-rated content is the largest group.
# - Release volume peaks around 2018–2019.

# %% [markdown]
# #### *Pie Chart*

# %%
x = df_new['rating_category'].value_counts()
labels =['Adult','Teen','Family','Kids','Unrated']
plt.figure(figsize=(4,4))
plt.pie(x,labels=labels,autopct='%1.1f%%')
plt.title("Distribution of Rating category")
plt.xlabel("Rating category")
plt.show()

# %% [markdown]
# - This pie chart shows how many titles are in each rating group.
# - **Adult** is the biggest group, so most titles are for mature viewers.
# - **Teen** is the next biggest group.
# - **Family** and **Kids** are smaller, so child-friendly content is less common.
# - **Unrated** titles are very few.

# %% [markdown]
# ### **Bivariate Analysis**

# %% [markdown]
# ### *Bar Plot*

# %%
plt.figure(figsize=(5,5))
sns.barplot(data=df_new1,y="duration",x="rating_category")
plt.title("Distribution of Release Year")
plt.xlabel("Rating Category")
plt.ylabel("Duration")
plt.show()

# %% [markdown]
# - The bar plot shows average length for each rating group.
# - Teen and Adult categories have the longest durations.
# - Kids content is much shorter than other groups.

# %% [markdown]
# #### *Line Plot*

# %%
plt.figure(figsize=(4,4))
sns.lineplot(data=df_new1,x="release_year",y=("duration"))
plt.title("Distribution of Release Year with duration")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# * Movie lengths increased sharply from the 1940s to the mid-1960s
# * Peak average duration occurred around the 1960s
# * High variability in movie lengths during the 1960s–1980s
# * Gradual decline in duration after the 1970s
# * Modern films (2000s onward) are shorter and more consistent
# * Overall trend: rise → peak → steady decline → stabilization

# %%
plt.figure(figsize=(4,4))
sns.lineplot(data=df_new2,x="release_year",y=("duration"))
plt.title("Distribution of Release Year with duration")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# * Values stay very low and flat until around the 1950s
# * Sharp spikes appear between the 1960s–1980s (high instability)
# * Peak occurs around the late 1970s–early 1980s
# * After 1990, values drop and fluctuate frequently
# * From 2000 onward, values stabilize at low levels
# * Overall trend: flat → volatile spikes → decline → low, stable pattern

# %% [markdown]
# #### *Scatter Plot*

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=df_new1,x="release_year",y="duration")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# * Most movies cluster between ~80–150 minutes
# * After 2000, many more movies are released (denser points)
# * Wide spread in durations, but majority stay in mid-range
# * Some outliers: very short (<50 min) and very long (>200 min) films
# * Older films (pre-1970) are fewer but often longer
# * Overall: high variation, but typical movie length stays around ~100–140 minutes

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=df_new2,x="release_year",y="duration")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most TV shows are of smaller duration(1-3 seasons)
# - The number of  releases increases very much after 2010.
# - Very long-running shows (duration above 10) are rare and appear as outliers.
# - The plot suggests Netflix content is skewed toward newer, shorter-run TV shows rather than long multi-season series.

# %% [markdown]
# DAY 6

# %% [markdown]
# ### **Multivariate Analysis**

# %% [markdown]
# #### *Heatmap*

# %%
df_new1_num=df_new1.select_dtypes(include='number')
df_new1_num.corr()
# Out:
#               release_year  duration
# release_year      1.000000 -0.206248
# duration         -0.206248  1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_new1_num.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - The correlation between release_year and duration is -0.21.
# - This is a weak negative relationship → as release year increases, duration tends to slightly decrease.
# - The value is close to 0, so the relationship is not strong.
# - This means newer content is only slightly shorter on average, but not by much.
# - There is no strong pattern between release year and duration.

# %%
df_new2_num=df_new2.select_dtypes(include='number')
df_new2_num.corr()
# Out:
#               release_year  duration
# release_year      1.000000 -0.081586
# duration         -0.081586  1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_new2_num.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - The correlation between release_year and duration is -0.082.
# - This is a weak negative relationship → as release year increases, duration tends to slightly decrease.
# - The value is close to 0, so the relationship is not strong.
# - This means newer content is only slightly shorter on average, but not by much.
# - There is no strong pattern between release year and duration.

# %% [markdown]
# #### *Pair Plot*

# %%
plt.figure(figsize=(5,6))
sns.pairplot(df_new1[['release_year','duration']])

# %% [markdown]
# - The pairplot shows no strong linear relationship between `release_year` and `duration`.
# - Points are scattered widely, so newer movies are not consistently longer or shorter.
# - Most movies cluster around typical durations, regardless of release year.
# - The trend is almost flat, confirming the weak negative correlation.

# %%
plt.figure(figsize=(5,6))
sns.pairplot(df_new2[['release_year','duration']])

# %% [markdown]
# - most releases are from 2010 onward.
# - Peak release activity is around 2018–2019.
# - TV shows are fewer and mostly short-run.
# - Ratings are skewed toward adult content, with teen content second-largest.
# - TV show durations are mostly 1–3 seasons; long series are rare.
# - Release year vs duration shows only a weak negative correlation.

# %% [markdown]
# -----

# %% [markdown]
# DAY 7

# %% [markdown]
# ### **CONCLUSION**

# %% [markdown]
# In this project, the Netflix Dataset was successfully cleaned and analyzed. Several changes were made to improve the quality of the data. Missing values in columns like director, cast, and country were handled by filling or removing them.The movies and tv shows are seperated to a file. The duration column was cleaned and converted into a proper numeric format, where movies are shown in minutes and TV shows in seasons.
#
# After cleaning, the dataset became more accurate and easy to use for analysis. The analysis showed that Netflix has more movies than TV shows, most content is released after 2010, and popular genres include drama and comedy. It also showed that content is mainly made for young and adult audiences.
#
# Overall, this project helped in understanding how to clean data, fix errors, and perform data analysis. It shows the importance of data preprocessing before doing any analysis.

# %% [markdown]
# #### *KEY INSIGHTS :*

# %% [markdown]
# - Movies dominated in netflix than tv shows.
# - In the dataset 6126 Moviesand 2664 Tv shows are  there.
# - Most content dominated by United States.
# - Most of the movies and tv shows target on adult audience.
# - After cleaning the dataset ,have 8790 entries.
# - The average release year is 2014.
# - The median release year is 2017.
# - The standard deviation of release year is 8.825.
# - Most of the directors are unknown.
# - Most of the cast are unknown.
# - Most of genre are drama & international movies.
# - A huge majority of the releases happened in the last 10-15 years.
# - The no.of releases started growing very fast after 2010.
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020.
# - long trail of circles to the left shows that releases before 2005 are rare and considered outliers.
# - The highest releases count are in 2018-2019.
# - Adult is biggest rating category,so most titles are mature viewers.
# - Teen and adult categories have the longest durations.
# - Kids content is much shorter than other group.
# - Movie length increased sharply from the 1940's to the mid 1960's.
# - Some outliers very short (<50 min) and very long (>200 min) films.
# - The correlation between release year and duration is -0.21.
# - The value is close to 0,so the relationship is not strong
# - No strong linear relationship between release year and duration
# - Tv show duration are mostly 1-3 seasons
